# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from pycaret.regression import *

# %%
 final = pd.read_csv('Data/df4.csv')

# %%
final.drop(columns='seller_id', inplace=True)

# %%
final.rename(columns={'Unnamed: 0':'seller'}, inplace=True)

# %%
final.value_counts()
# Out:
# seller  total_vendas  review_score  antecipacao_entrega
# 0       2020          5.0            11.0                  1
# 2028    4             5.0            0.0                   1
# 2054    3             5.0            12.0                  1
# 2055    3             5.0            14.0                  1
# 2056    3             1.0           -1.0                   1
#                                                           ..
# 1032    15            5.0            15.0                  1
# 1033    15            5.0            11.0                  1
# 1034    15            2.0            0.0                   1
# 1035    15            4.0            8.0                   1
# 3089    1             5.0            23.0                  1
# Length: 3090, dtype: int64

# %%
regression = setup(data = final, remove_outliers=True, unknown_categorical_method='most_frequent', target = 'review_score', session_id=42, imputation_type='iterative', normalize=True)
# Out:
# <style type="text/css">
# #T_f48e9_row27_col1, #T_f48e9_row38_col1, #T_f48e9_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f48e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f48e9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f48e9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f48e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f48e9_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f48e9_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_f48e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f48e9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f48e9_row1_col1" class="data row1 col1" >review_score</td>
#     </tr>
#     <tr>
# ...

# %%
best_model = compare_models()
best_model
# Out:
# <style type="text/css">
# #T_3b2bb th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
# Out:
# <style type="text/css">
# </style>
# <table id="T_e907f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e907f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e907f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e907f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e907f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e907f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e907f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e907f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e907f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e907f_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_e907f_row0_col1" class="data row0 col1" >0.6381</td>
# ...

# %%
final2 = pd.read_csv('Data/df1.csv')

# %%
final2
# Out:
#         seller            seller_city seller_state  order_item_id   price  \
# 0            0   sao joaquim da barra           SP            1.0  185.00
# 1            1   sao joaquim da barra           SP            2.0  185.00
# 2            2    sao jose dos campos           SP            1.0   79.79
# 3            3               ilicinea           MG            1.0  149.00
# 4            4               ilicinea           MG            1.0  179.99
# ...        ...                    ...          ...            ...     ...
# 113126  113126            santo andre           SP            1.0  226.77
# 113127  113127         rio de janeiro           RJ            1.0  199.99
# 113128  113128                  betim           MG            1.0  215.97
# 113129  113129  sao bernardo do campo           SP            1.0   50.95
# 113130  113130              sao paulo           SP            1.0   32.90
#
#         freight_value order_status_x   product_category_name  \
# ...

# %%
final2.drop(columns=['order_id', 'seller_id', 'customer_id_x', 'product_id', 'order_purchase_timestamp_y', 'order_approved_at_y', 'order_delivered_carrier_date_y', 'order_delivered_customer_date_y', 'order_estimated_delivery_date_y', 'review_creation_date' ,'review_answer_timestamp'], inplace=True)

# %%
final2.drop(columns=['order_approved_at_x', 'Unnamed: 0_y', 'customer_id_y', 'seller_zip_code_prefix' ], inplace=True)

# %%
final2.drop(columns='order_status_y', inplace=True)

# %%
final2.rename(columns={'Unnamed: 0':'seller'}, inplace=True)

# %%
final2.dropna(inplace=True)

# %%
regression2 = setup(data = final2, remove_outliers=True, unknown_categorical_method='most_frequent', target = 'review_score', session_id=42, imputation_type='iterative', normalize=True, n_jobs=-3)
# Out:
# <style type="text/css">
# #T_0aae9_row27_col1, #T_0aae9_row38_col1, #T_0aae9_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0aae9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0aae9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0aae9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0aae9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0aae9_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_0aae9_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_0aae9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0aae9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0aae9_row1_col1" class="data row1 col1" >review_score</td>
#     </tr>
#     <tr>
# ...

# %%
best_model2 = compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=94)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          20:47:10
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Regression
# <style type="text/css">
# #T_be791 th {
#   text-align: left;
# }
# #T_be791_row0_col0, #T_be791_row0_col1, #T_be791_row0_col2, #T_be791_row0_col3, #T_be791_row0_col4, #T_be791_row0_col5, #T_be791_row0_col6, #T_be791_row0_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_be791">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be791_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_be791_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_be791_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_be791_level0_col3" class="col_heading level0 col3" >RMSE</th>
# ...
