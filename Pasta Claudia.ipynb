# %%
import pandas as pd
import numpy as np
import os
import re
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import glob
import pandas as pd
from sklearn.model_selection import train_test_split
from pycaret.classification import *

# %% [markdown]
# # Descrição dos dados

# %% [markdown]
# Each feature or columns of different csv files are described below:
#
# * The  `olist_customers_dataset.csv` contain following features:
#
# Feature | Description
# ----------|---------------
# **customer_id** | Id of the consumer who made the purchase.
# **customer_unique_id**    | Unique Id of the consumer.
# **customer_zip_code_prefix** | Zip Code of the location of the consumer.
# **customer_city** | Name of the City from where order is made.
# **customer_state** |  State Code from where order is made(Ex- sao paulo-SP).
#
# * The `olist_sellers_dataset.csv` contains following features:
#
# Feature | Description
# ----------|---------------
# **seller_id** |   Unique Id of the seller registered in olist.
# **seller_zip_code_prefix** | Zip Code of the location of the seller.
# **seller_city** | Name of the City of the seller.
# **seller_state** | State Code (Ex- sao paulo-SP)
#
#
# * The `olist_order_items_dataset.csv`  contain following features:
#
# Feature | Description
# ----------|---------------
# **order_id** | A unique id of order made by the consumers.
# **order_item_id** | A Unique id given to each item ordered in the order.
# **product_id** |A unique id given to each product available on the site.
# **seller_id** | Unique Id of the seller registered in olist.
# **shipping_limit_date** | The date before which shipping of the ordered    product must be completed.
# **price** | Actual price of the products ordered .
# **freight_value** | Price rate at which a product is delivered from one point to another.
#
# * The `olist_order_payments_dataset.csv` contain following features:
#
# Feature | Description
# ----------|---------------
# **order_id** | A unique id of order made by the consumers.
# **payment_sequential** | sequences of the payments made in case of EMI.
# **payment_type** |  mode of payment used.(Ex-Credit Card)
# **payment_installments** | number of installments in case of EMI purchase.
# **payment_value** | Total amount paid for the purshase order.
#
#
#
# * The `olist_orders_dataset.csv`  contain following features:
#
# Feature | Description
# ----------|---------------
# **order_id** | A unique id of order made by the consumers.
# **customer_id** | Id of the consumer who made the purchase.
# **order_status** | status of the order made i.e delivered, shipped etc.
# **order_purchase_timestamp** | Timestamp of the purchase.
# **order_approved_at** | Timestamp of the order approval.
# **order_delivered_carrier_date** | delivery date at which carrier made the delivery.
# **order_delivered_customer_date** | date at which customer got the product.
# **order_estimated_delivery_date** | estimated delivery date of the products.
#
#
# * The `olist_order_reviews_dataset.csv`  contain following features:
#
# Feature | Description
# ----------|---------------
# **review_id** |Id of the review given on the product ordered by the order id.
# **order_id** |  A unique id of order made by the consumers.
# **review_score** | review score given by the customer for each order on the scale of 1–5.
# **review_comment_title** | Title of the review
# **review_comment_message** | Review comments posted by the consumer for each order.
# **review_creation_date** |Timestamp of the review when it is created.
# **review_answer_timestamp** | Timestamp of the review answered.
#
#
# * The `olist_products_dataset.csv` contain following features:
#
# Feature | Description
# ----------|---------------
# **product_id** | A unique identifier for the proposed project.
# **product_category_name** | Name of the product category
# **product_name_lenght** | length of the string which specify the name given to the products ordered.
# **product_description_lenght** | length of the description written for each product ordered on the site.
# **product_photos_qty** | Number of photos of each product ordered available on the shopping portal.
# **product_weight_g** | Weight of the products ordered in grams.
# **product_length_cm** | Length of the products ordered in centimeters.
# **product_height_cm** | Height of the products ordered in centimeters.
# **product_width_cm** | width of the product ordered in centimeters.

# %%
caminho = r'C:\Users\USER\Desktop\Ironhack\Github\Projeto Final - Olist\Data'
lista = []
df = pd.DataFrame()

for f in os.listdir (caminho + "/"):
    if f != 'product_category_name_translation.csv':
        frames = pd.read_csv(caminho + "/" + f)
    df = df.append(frames, ignore_index= True)
df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                   14409.0                 franca             SP
# 1                    9790.0  sao bernardo do campo             SP
# 2                    1151.0              sao paulo             SP
# 3                    8775.0        mogi das cruzes             SP
# 4                   13056.0               campinas             SP
#
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                          NaN              NaN              NaN
# 1                          NaN              NaN              NaN
# 2                          NaN              NaN              NaN
# 3                          NaN              NaN              NaN
# 4                          NaN              NaN              NaN
#
#   geolocation_city geolocation_state order_id order_status  \
# 0              NaN               NaN      NaN          NaN
# 1              NaN               NaN      NaN          NaN
# 2              NaN               NaN      NaN          NaN
# 3              NaN               NaN      NaN          NaN
# 4              NaN               NaN      NaN          NaN
#
#   order_purchase_timestamp order_approved_at order_delivered_carrier_date  \
# 0                      NaN               NaN                          NaN
# 1                      NaN               NaN                          NaN
# 2                      NaN               NaN                          NaN
# 3                      NaN               NaN                          NaN
# 4                      NaN               NaN                          NaN
#
#   order_delivered_customer_date order_estimated_delivery_date  order_item_id  \
# 0                           NaN                           NaN            NaN
# 1                           NaN                           NaN            NaN
# 2                           NaN                           NaN            NaN
# 3                           NaN                           NaN            NaN
# 4                           NaN                           NaN            NaN
#
#   product_id seller_id shipping_limit_date  price  freight_value  \
# 0        NaN       NaN                 NaN    NaN            NaN
# 1        NaN       NaN                 NaN    NaN            NaN
# 2        NaN       NaN                 NaN    NaN            NaN
# 3        NaN       NaN                 NaN    NaN            NaN
# 4        NaN       NaN                 NaN    NaN            NaN
#
#    payment_sequential payment_type  payment_installments  payment_value  \
# 0                 NaN          NaN                   NaN            NaN
# 1                 NaN          NaN                   NaN            NaN
# 2                 NaN          NaN                   NaN            NaN
# 3                 NaN          NaN                   NaN            NaN
# 4                 NaN          NaN                   NaN            NaN
#
#   review_id  review_score review_comment_title review_comment_message  \
# 0       NaN           NaN                  NaN                    NaN
# 1       NaN           NaN                  NaN                    NaN
# 2       NaN           NaN                  NaN                    NaN
# 3       NaN           NaN                  NaN                    NaN
# 4       NaN           NaN                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp product_category_name  \
# 0                  NaN                     NaN                   NaN
# 1                  NaN                     NaN                   NaN
# 2                  NaN                     NaN                   NaN
# 3                  NaN                     NaN                   NaN
# 4                  NaN                     NaN                   NaN
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                  NaN                         NaN                 NaN
# 1                  NaN                         NaN                 NaN
# 2                  NaN                         NaN                 NaN
# 3                  NaN                         NaN                 NaN
# 4                  NaN                         NaN                 NaN
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0               NaN                NaN                NaN               NaN
# 1               NaN                NaN                NaN               NaN
# 2               NaN                NaN                NaN               NaN
# 3               NaN                NaN                NaN               NaN
# 4               NaN                NaN                NaN               NaN
#
#    seller_zip_code_prefix seller_city seller_state
# 0                     NaN         NaN          NaN
# 1                     NaN         NaN          NaN
# 2                     NaN         NaN          NaN
# 3                     NaN         NaN          NaN
# 4                     NaN         NaN          NaN

# %%
df.shape
# Out:
# (1553946, 44)

# %% [markdown]
# ## Analisando dados

# %%
df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                   14409.0                 franca             SP
# 1                    9790.0  sao bernardo do campo             SP
# 2                    1151.0              sao paulo             SP
# 3                    8775.0        mogi das cruzes             SP
# 4                   13056.0               campinas             SP
#
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                          NaN              NaN              NaN
# 1                          NaN              NaN              NaN
# 2                          NaN              NaN              NaN
# 3                          NaN              NaN              NaN
# 4                          NaN              NaN              NaN
#
#   geolocation_city geolocation_state order_id order_status  \
# 0              NaN               NaN      NaN          NaN
# 1              NaN               NaN      NaN          NaN
# 2              NaN               NaN      NaN          NaN
# 3              NaN               NaN      NaN          NaN
# 4              NaN               NaN      NaN          NaN
#
#   order_purchase_timestamp order_approved_at order_delivered_carrier_date  \
# 0                      NaN               NaN                          NaN
# 1                      NaN               NaN                          NaN
# 2                      NaN               NaN                          NaN
# 3                      NaN               NaN                          NaN
# 4                      NaN               NaN                          NaN
#
#   order_delivered_customer_date order_estimated_delivery_date  order_item_id  \
# 0                           NaN                           NaN            NaN
# 1                           NaN                           NaN            NaN
# 2                           NaN                           NaN            NaN
# 3                           NaN                           NaN            NaN
# 4                           NaN                           NaN            NaN
#
#   product_id seller_id shipping_limit_date  price  freight_value  \
# 0        NaN       NaN                 NaN    NaN            NaN
# 1        NaN       NaN                 NaN    NaN            NaN
# 2        NaN       NaN                 NaN    NaN            NaN
# 3        NaN       NaN                 NaN    NaN            NaN
# 4        NaN       NaN                 NaN    NaN            NaN
#
#    payment_sequential payment_type  payment_installments  payment_value  \
# 0                 NaN          NaN                   NaN            NaN
# 1                 NaN          NaN                   NaN            NaN
# 2                 NaN          NaN                   NaN            NaN
# 3                 NaN          NaN                   NaN            NaN
# 4                 NaN          NaN                   NaN            NaN
#
#   review_id  review_score review_comment_title review_comment_message  \
# 0       NaN           NaN                  NaN                    NaN
# 1       NaN           NaN                  NaN                    NaN
# 2       NaN           NaN                  NaN                    NaN
# 3       NaN           NaN                  NaN                    NaN
# 4       NaN           NaN                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp product_category_name  \
# 0                  NaN                     NaN                   NaN
# 1                  NaN                     NaN                   NaN
# 2                  NaN                     NaN                   NaN
# 3                  NaN                     NaN                   NaN
# 4                  NaN                     NaN                   NaN
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                  NaN                         NaN                 NaN
# 1                  NaN                         NaN                 NaN
# 2                  NaN                         NaN                 NaN
# 3                  NaN                         NaN                 NaN
# 4                  NaN                         NaN                 NaN
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0               NaN                NaN                NaN               NaN
# 1               NaN                NaN                NaN               NaN
# 2               NaN                NaN                NaN               NaN
# 3               NaN                NaN                NaN               NaN
# 4               NaN                NaN                NaN               NaN
#
#    seller_zip_code_prefix seller_city seller_state
# 0                     NaN         NaN          NaN
# 1                     NaN         NaN          NaN
# 2                     NaN         NaN          NaN
# 3                     NaN         NaN          NaN
# 4                     NaN         NaN          NaN

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing.head()
# Out:
#                           Total   Percent
# seller_state            1547756  0.996017
# seller_city             1547756  0.996017
# seller_zip_code_prefix  1547756  0.996017
# review_comment_title    1542378  0.992556
# product_photos_qty      1521605  0.979188

# %%
df.describe().transpose()
# Out:
#                                  count          mean           std  \
# customer_zip_code_prefix       99441.0  35137.474583  29797.938996
# geolocation_zip_code_prefix  1000163.0  36574.166466  30549.335710
# geolocation_lat              1000163.0    -21.176153      5.715866
# geolocation_lng              1000163.0    -46.390541      4.269748
# order_item_id                 112650.0      1.197834      0.705124
# price                         112650.0    120.653739    183.633928
# freight_value                 112650.0     19.990320     15.806405
# payment_sequential            103886.0      1.092679      0.706584
# payment_installments          103886.0      2.853349      2.687051
# payment_value                 103886.0    154.100380    217.494064
# review_score                   99224.0      4.086421      1.347579
# product_name_lenght            32341.0     48.476949     10.245741
# product_description_lenght     32341.0    771.495285    635.115225
# product_photos_qty             32341.0      2.188986      1.736766
# product_weight_g               32949.0   2276.472488   4282.038731
# product_length_cm              32949.0     30.815078     16.914458
# product_height_cm              32949.0     16.937661     13.637554
# product_width_cm               32949.0     23.196728     12.079047
# seller_zip_code_prefix          6190.0  32291.059451  32710.810852
#
#                                      min           25%           50%  \
# customer_zip_code_prefix     1003.000000  11347.000000  24416.000000
# geolocation_zip_code_prefix  1001.000000  11075.000000  26530.000000
# geolocation_lat               -36.605374    -23.603546    -22.919377
# geolocation_lng              -101.466766    -48.573172    -46.637879
# order_item_id                   1.000000      1.000000      1.000000
# price                           0.850000     39.900000     74.990000
# freight_value                   0.000000     13.080000     16.260000
# payment_sequential              1.000000      1.000000      1.000000
# payment_installments            0.000000      1.000000      1.000000
# payment_value                   0.000000     56.790000    100.000000
# review_score                    1.000000      4.000000      5.000000
# product_name_lenght             5.000000     42.000000     51.000000
# product_description_lenght      4.000000    339.000000    595.000000
# product_photos_qty              1.000000      1.000000      1.000000
# product_weight_g                0.000000    300.000000    700.000000
# product_length_cm               7.000000     18.000000     25.000000
# product_height_cm               2.000000      8.000000     13.000000
# product_width_cm                6.000000     15.000000     20.000000
# seller_zip_code_prefix       1001.000000   7093.250000  14940.000000
#
#                                       75%           max
# customer_zip_code_prefix     58900.000000  99990.000000
# geolocation_zip_code_prefix  63504.000000  99990.000000
# geolocation_lat                -19.979620     45.065933
# geolocation_lng                -43.767709    121.105394
# order_item_id                    1.000000     21.000000
# price                          134.900000   6735.000000
# freight_value                   21.150000    409.680000
# payment_sequential               1.000000     29.000000
# payment_installments             4.000000     24.000000
# payment_value                  171.837500  13664.080000
# review_score                     5.000000      5.000000
# product_name_lenght             57.000000     76.000000
# product_description_lenght     972.000000   3992.000000
# product_photos_qty               3.000000     20.000000
# product_weight_g              1900.000000  40425.000000
# product_length_cm               38.000000    105.000000
# product_height_cm               21.000000    105.000000
# product_width_cm                30.000000    118.000000
# seller_zip_code_prefix       64812.250000  99730.000000

# %%
df.isna().sum()
# Out:
# customer_id                      1355064
# customer_unique_id               1454505
# customer_zip_code_prefix         1454505
# customer_city                    1454505
# customer_state                   1454505
# geolocation_zip_code_prefix       553783
# geolocation_lat                   553783
# geolocation_lng                   553783
# geolocation_city                  553783
# geolocation_state                 553783
# order_id                         1138745
# order_status                     1454505
# order_purchase_timestamp         1454505
# order_approved_at                1454665
# order_delivered_carrier_date     1456288
# order_delivered_customer_date    1457470
# order_estimated_delivery_date    1454505
# order_item_id                    1441296
# product_id                       1408345
# seller_id                        1435106
# shipping_limit_date              1441296
# price                            1441296
# freight_value                    1441296
# payment_sequential               1450060
# payment_type                     1450060
# payment_installments             1450060
# payment_value                    1450060
# review_id                        1454722
# review_score                     1454722
# review_comment_title             1542378
# review_comment_message           1512969
# review_creation_date             1454722
# review_answer_timestamp          1454722
# product_category_name            1521605
# product_name_lenght              1521605
# product_description_lenght       1521605
# product_photos_qty               1521605
# product_weight_g                 1520997
# product_length_cm                1520997
# product_height_cm                1520997
# product_width_cm                 1520997
# seller_zip_code_prefix           1547756
# seller_city                      1547756
# seller_state                     1547756
# dtype: int64

# %% [markdown]
# ## Manipulação de valores ausentes

# %%
index = (df[df['order_delivered_customer_date'].isnull() == True].index.values)

df["order_approved_at"].fillna(df["order_purchase_timestamp"], inplace=True)
df["order_delivered_customer_date"].fillna(df["order_estimated_delivery_date"], inplace=True)

# %% [markdown]
# ## Fazendo drop de colunas com numero elevado de nulos

# %%
df.drop(['seller_state', 'seller_city', 'seller_zip_code_prefix', 'review_comment_title', 'product_photos_qty'],axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553946 entries, 0 to 1553945
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   customer_id                    198882 non-null   object
#  1   customer_unique_id             99441 non-null    object
#  2   customer_zip_code_prefix       99441 non-null    float64
#  3   customer_city                  99441 non-null    object
#  4   customer_state                 99441 non-null    object
#  5   geolocation_zip_code_prefix    1000163 non-null  float64
#  6   geolocation_lat                1000163 non-null  float64
#  7   geolocation_lng                1000163 non-null  float64
#  8   geolocation_city               1000163 non-null  object
#  9   geolocation_state              1000163 non-null  object
#  10  order_id                       415201 non-null   object
#  11  order_status                   99441 non-null    object
#  12  order_purchase_timestamp       99441 non-null    object
#  13  order_approved_at              99441 non-null    object
#  14  order_delivered_carrier_date   97658 non-null    object
#  15  order_delivered_customer_date  99441 non-null    object
#  16  order_estimated_delivery_date  99441 non-null    object
#  17  order_item_id                  112650 non-null   float64
#  18  product_id                     145601 non-null   object
#  19  seller_id                      118840 non-null   object
#  20  shipping_limit_date            112650 non-null   object
#  21  price                          112650 non-null   float64
#  22  freight_value                  112650 non-null   float64
#  23  payment_sequential             103886 non-null   float64
#  24  payment_type                   103886 non-null   object
#  25  payment_installments           103886 non-null   float64
#  26  payment_value                  103886 non-null   float64
#  27  review_id                      99224 non-null    object
#  28  review_score                   99224 non-null    float64
#  29  review_comment_message         40977 non-null    object
#  30  review_creation_date           99224 non-null    object
#  31  review_answer_timestamp        99224 non-null    object
#  32  product_category_name          32341 non-null    object
#  33  product_name_lenght            32341 non-null    float64
#  34  product_description_lenght     32341 non-null    float64
#  35  product_weight_g               32949 non-null    float64
#  36  product_length_cm              32949 non-null    float64
#  37  product_height_cm              32949 non-null    float64
#  38  product_width_cm               32949 non-null    float64
# dtypes: float64(17), object(22)
# memory usage: 462.4+ MB

# %%
df.shape
# Out:
# (1553946, 39)

# %% [markdown]
# ## Formatação de colunas

# %% [markdown]
# A coluna de data precisa ser formatada. Utilizaremos o formato datetime extraindo os atributos de tempo dessas colunas

# %%
times_cols = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_estimated_delivery_date', 'order_delivered_customer_date']
for col in times_cols:
    df[col] = pd.to_datetime(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553946 entries, 0 to 1553945
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   customer_id                    198882 non-null   object
#  1   customer_unique_id             99441 non-null    object
#  2   customer_zip_code_prefix       99441 non-null    float64
#  3   customer_city                  99441 non-null    object
#  4   customer_state                 99441 non-null    object
#  5   geolocation_zip_code_prefix    1000163 non-null  float64
#  6   geolocation_lat                1000163 non-null  float64
#  7   geolocation_lng                1000163 non-null  float64
#  8   geolocation_city               1000163 non-null  object
#  9   geolocation_state              1000163 non-null  object
#  10  order_id                       415201 non-null   object
#  11  order_status                   99441 non-null    object
#  12  order_purchase_timestamp       99441 non-null    datetime64[ns]
#  13  order_approved_at              99441 non-null    datetime64[ns]
#  14  order_delivered_carrier_date   97658 non-null    datetime64[ns]
#  15  order_delivered_customer_date  99441 non-null    datetime64[ns]
#  16  order_estimated_delivery_date  99441 non-null    datetime64[ns]
#  17  order_item_id                  112650 non-null   float64
#  18  product_id                     145601 non-null   object
#  19  seller_id                      118840 non-null   object
#  20  shipping_limit_date            112650 non-null   object
#  21  price                          112650 non-null   float64
#  22  freight_value                  112650 non-null   float64
#  23  payment_sequential             103886 non-null   float64
#  24  payment_type                   103886 non-null   object
#  25  payment_installments           103886 non-null   float64
#  26  payment_value                  103886 non-null   float64
#  27  review_id                      99224 non-null    object
#  28  review_score                   99224 non-null    float64
#  29  review_comment_message         40977 non-null    object
#  30  review_creation_date           99224 non-null    object
#  31  review_answer_timestamp        99224 non-null    object
#  32  product_category_name          32341 non-null    object
#  33  product_name_lenght            32341 non-null    float64
#  34  product_description_lenght     32341 non-null    float64
#  35  product_weight_g               32949 non-null    float64
#  36  product_length_cm              32949 non-null    float64
#  37  product_height_cm              32949 non-null    float64
#  38  product_width_cm               32949 non-null    float64
# dtypes: datetime64[ns](5), float64(17), object(17)
# memory usage: 462.4+ MB

# %% [markdown]
# ### Extraindo atributos para data de compra - Ano e Mês

# %% [markdown]
# Abaixo converteremos um  datetime objeto contendo data e hora atuais para diferentes formatos.

# %%
df['order_purchase_timestamp'].describe()
# Out:
# count                   99441
# unique                  98875
# top       2018-04-11 10:48:14
# freq                        3
# first     2016-09-04 21:15:19
# last      2018-10-17 17:30:18
# Name: order_purchase_timestamp, dtype: object

# %%
df['order_purchase_year'] = df['order_purchase_timestamp'].apply(lambda x: x.year)
df['order_purchase_month'] = df['order_purchase_timestamp'].apply(lambda x: x.month)
df['order_purchase_month_name'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%b'))
df['order_purchase_year_month'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%Y%m'))
df['order_purchase_date'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%Y%m%d'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [63], line 3
#       1 df['order_purchase_year'] = df['order_purchase_timestamp'].apply(lambda x: x.year)
#       2 df['order_purchase_month'] = df['order_purchase_timestamp'].apply(lambda x: x.month)
# ----> 3 df['order_purchase_month_name'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%b'))
#       4 df['order_purchase_year_month'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%Y%m'))
#       5 df['order_purchase_date'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%Y%m%d'))
#
# File C:\ProgramData\Anaconda3\envs\pycaret\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File C:\ProgramData\Anaconda3\envs\pycaret\lib\site-packages\pandas\core\apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# -> 1088 return self.apply_standard()
#
# File C:\ProgramData\Anaconda3\envs\pycaret\lib\site-packages\pandas\core\apply.py:1143, in SeriesApply.apply_standard(self)
#    1137         values = obj.astype(object)._values
#    1138         # error: Argument 2 to "map_infer" has incompatible type
#    1139         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1140         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1141         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142         # "Callable[[Any], Any]"
# -> 1143         mapped = lib.map_infer(
#    1144             values,
#    1145             f,  # type: ignore[arg-type]
#    1146             convert=self.convert_dtype,
#    1147         )
#    1149 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1150     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1151     #  See also GH#25959 regarding EA support
#    1152     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File C:\ProgramData\Anaconda3\envs\pycaret\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Cell In [63], line 3, in <lambda>(x)
#       1 df['order_purchase_year'] = df['order_purchase_timestamp'].apply(lambda x: x.year)
#       2 df['order_purchase_month'] = df['order_purchase_timestamp'].apply(lambda x: x.month)
# ----> 3 df['order_purchase_month_name'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%b'))
#       4 df['order_purchase_year_month'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%Y%m'))
#       5 df['order_purchase_date'] = df['order_purchase_timestamp'].apply(lambda x: x.strftime('%Y%m%d'))
#
# File C:\ProgramData\Anaconda3\envs\pycaret\lib\site-packages\pandas\_libs\tslibs\nattype.pyx:75, in pandas._libs.tslibs.nattype._make_error_func.f()
#
# ValueError: NaTType does not support strftime

# %%
df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                   14409.0                 franca             SP
# 1                    9790.0  sao bernardo do campo             SP
# 2                    1151.0              sao paulo             SP
# 3                    8775.0        mogi das cruzes             SP
# 4                   13056.0               campinas             SP
#
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                          NaN              NaN              NaN
# 1                          NaN              NaN              NaN
# 2                          NaN              NaN              NaN
# 3                          NaN              NaN              NaN
# 4                          NaN              NaN              NaN
#
#   geolocation_city geolocation_state order_id order_status  \
# 0              NaN               NaN      NaN          NaN
# 1              NaN               NaN      NaN          NaN
# 2              NaN               NaN      NaN          NaN
# 3              NaN               NaN      NaN          NaN
# 4              NaN               NaN      NaN          NaN
#
#   order_purchase_timestamp order_approved_at order_delivered_carrier_date  \
# 0                      NaT               NaT                          NaT
# 1                      NaT               NaT                          NaT
# 2                      NaT               NaT                          NaT
# 3                      NaT               NaT                          NaT
# 4                      NaT               NaT                          NaT
#
#   order_delivered_customer_date order_estimated_delivery_date  order_item_id  \
# 0                           NaT                           NaT            NaN
# 1                           NaT                           NaT            NaN
# 2                           NaT                           NaT            NaN
# 3                           NaT                           NaT            NaN
# 4                           NaT                           NaT            NaN
#
#   product_id seller_id shipping_limit_date  price  freight_value  \
# 0        NaN       NaN                 NaN    NaN            NaN
# 1        NaN       NaN                 NaN    NaN            NaN
# 2        NaN       NaN                 NaN    NaN            NaN
# 3        NaN       NaN                 NaN    NaN            NaN
# 4        NaN       NaN                 NaN    NaN            NaN
#
#    payment_sequential payment_type  payment_installments  payment_value  \
# 0                 NaN          NaN                   NaN            NaN
# 1                 NaN          NaN                   NaN            NaN
# 2                 NaN          NaN                   NaN            NaN
# 3                 NaN          NaN                   NaN            NaN
# 4                 NaN          NaN                   NaN            NaN
#
#   review_id  review_score review_comment_message review_creation_date  \
# 0       NaN           NaN                    NaN                  NaN
# 1       NaN           NaN                    NaN                  NaN
# 2       NaN           NaN                    NaN                  NaN
# 3       NaN           NaN                    NaN                  NaN
# 4       NaN           NaN                    NaN                  NaN
#
#   review_answer_timestamp product_category_name  product_name_lenght  \
# 0                     NaN                   NaN                  NaN
# 1                     NaN                   NaN                  NaN
# 2                     NaN                   NaN                  NaN
# 3                     NaN                   NaN                  NaN
# 4                     NaN                   NaN                  NaN
#
#    product_description_lenght  product_weight_g  product_length_cm  \
# 0                         NaN               NaN                NaN
# 1                         NaN               NaN                NaN
# 2                         NaN               NaN                NaN
# 3                         NaN               NaN                NaN
# 4                         NaN               NaN                NaN
#
#    product_height_cm  product_width_cm  order_purchase_year  \
# 0                NaN               NaN                  NaN
# 1                NaN               NaN                  NaN
# 2                NaN               NaN                  NaN
# 3                NaN               NaN                  NaN
# 4                NaN               NaN                  NaN
#
#    order_purchase_month
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %% [markdown]
# ## Verificando dados Cidade

# %% [markdown]
# Podemos ver que não há valor nulo no conjunto de dados dos Clientes (Customers)
#
# AgTentaremos encontrar dados de estado e cidade únicos no Conjunto de Dados de Clientes

# %%
df.customer_city.unique()
# Out:
# array(['franca', 'sao bernardo do campo', 'sao paulo', ..., 'sao rafael',
#        'eugenio de castro', nan], dtype=object)

# %%
len(df.customer_city.unique())
# Out:
# 4120

# %% [markdown]
# ## Verificando dados Estados

# %%
df.customer_state.unique()
# Out:
# array(['SP', 'SC', 'MG', 'PR', 'RJ', 'RS', 'PA', 'GO', 'ES', 'BA', 'MA',
#        'MS', 'CE', 'DF', 'RN', 'PE', 'MT', 'AM', 'AP', 'AL', 'RO', 'PB',
#        'TO', 'PI', 'AC', 'SE', 'RR', nan], dtype=object)

# %%
len(df.customer_state.unique())
# Out:
# 28

# %% [markdown]
# ## Categoria de produto mais comprada

# %% [markdown]
# No banco de dados contam 71 categorias diferentes. Nesta pimeira etapa vamos excluir as duplicatas de dados utilizando como base o 'customer_unique_id' e o 'customer_city'

# %%
top_10_cities=df['customer_city'].value_counts().nlargest(10)
top_10_cities
# Out:
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: customer_city, dtype: int64

# %% [markdown]
# ### Por cidade

# %%
cities=df['customer_city'].value_counts(ascending=True)
cities[0:20]
# Out:
# eugenio de castro     1
# monteiropolis         1
# campo florido         1
# alto sao joao         1
# paulistania           1
# taquarana             1
# castanheiras          1
# humberto de campos    1
# nova brescia          1
# chaval                1
# curralinho            1
# tocos do moji         1
# marilac               1
# rio doce              1
# chiapetta             1
# tapera                1
# suzanapolis           1
# monte belo do sul     1
# lagoa do piaui        1
# riversul              1
# Name: customer_city, dtype: int64

# %%
cidade = df["customer_city"].nunique()
c1 = df.groupby('customer_city')['customer_id'].nunique().sort_values(ascending=False)
c2 = c1.head(10)
print(c2)
round(c2.sum()/df.shape[0]*100,1) #% de pedidos pelas top 10 cidades
c2.plot(kind="bar")

# %%
df = df.drop_duplicates(subset=["customer_unique_id"])
df["customer_city"] = df["customer_city"].str.capitalize()
df.head()

# %%
clientes_por_cidade = df.groupby("customer_city").count()["customer_unique_id"].reset_index().sort_values(by="customer_unique_id",ascending=False).head(10)
clientes_por_cidade.rename(columns = {"customer_unique_id":"total"}, inplace=True)
clientes_por_cidade

# %% [markdown]
# ### Por Estado

# %%
clientes_por_estado = df.groupby(["customer_state"]).count()["customer_unique_id"].reset_index().sort_values(by="customer_unique_id",ascending=False).head(10)
clientes_por_estado.rename(columns = {"customer_unique_id":"total"}, inplace=True)
clientes_por_estado

# %%
Supermecado, Tecnologia, Casa e Moveis, Eletrodomesticos, Esportes, Ferramentas, Construção, Industria e Comercio
Saude, Beleza e Perfumaria, Moda, Bebes, Brinquedos, Papelaria, Pet Shop, Mala, Mochila e Acessórios, Seguro e Servicos, Decoracao
