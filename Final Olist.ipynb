# %%
import pandas as pd
import numpy as np
import os
import bisect 
import pandas as pd
from sklearn.model_selection import train_test_split
from pycaret.classification import *

# %%
itens = pd.read_csv("Data/itens.csv") 
ordens = pd.read_csv("Data/ordens.csv")
produtos = pd.read_csv("Data/produtos.csv")
geolocal = pd.read_csv("Data/geolocal.csv")
clientes = pd.read_csv("Data/clientes.csv")
avaliacoes = pd.read_csv('Data/avaliacoes.csv')
vendedores = pd.read_csv("Data/vendedores.csv")
pagamentos = pd.read_csv("Data/pagamentos.csv")

# %%
es = pd.read_csv("data\olist_sellers_dataset.csv") #seller

# %% [markdown]
# ## Lendo dados

# %% [markdown]
# ## Clientes

# %%
clientes['customer_return'] = clientes.duplicated(subset=['customer_unique_id']).astype(int)
clientes['customer_return'].value_counts()
# Out:
# 0    96096
# 1     3345
# Name: customer_return, dtype: int64

# %%
clientes.drop(['customer_city', 'customer_unique_id'], axis=1, inplace=True)
clientes.rename(columns={"clientes_estado": "clientes_code"}, inplace=True)

# %%
clientes.to_csv('clientes.csv')

# %% [markdown]
# ## Geolocalização

# %% [markdown]
# Este conjunto de dados contém CEPs brasileiros e suas coordenadas lat/lng.

# %%
geolocal.shape
# Out:
# (738332, 7)

# %% [markdown]
# Eliminação de colunas indesejadas e duplicatas para manter apenas um par de latitude/longitude por prefixo de código postal.

# %%
geolocal = geolocal.drop(['geolocation_city', 'geolocation_state'], axis=1)
geolocal = geolocal.drop_duplicates(subset = ['geolocation_zip_code_prefix'],ignore_index=True)

# %% [markdown]
# Criar 2 novos dataframe para juntar com os dados do cliente posteriormente

# %%
geo_customer = geolocal.rename(columns={"geolocation_zip_code_prefix":"customer_zip_code_prefix",
                                                  "geolocation_lat":"customer_lat",
                                                  "geolocation_lng":"customer_lng"})
geo_seller = geolocal.rename(columns={"geolocation_zip_code_prefix":"seller_zip_code_prefix",
                                                  "geolocation_lat":"seller_lat",
                                                  "geolocation_lng":"seller_lng"})
geo_customer.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  customer_zip_code_prefix  customer_lat  \
# 0             0           0                      1037    -23.545621
# 1             1           1                      1046    -23.546081
# 2             3           3                      1041    -23.544392
#
#    customer_lng
# 0    -46.639292
# 1    -46.644820
# 2    -46.639499

# %%
#geolocal.to_csv('geolocal.csv')

# %% [markdown]
# ## Itens

# %% [markdown]
# Este conjunto de dados contém informações sobre os produtos em cada pedido. Os preços estão em reais. O valor do frete é calculado de acordo com as medidas e peso de cada item.

# %%
print(itens.shape)
itens.head(3)
# Out:
# (112650, 8)
#    Unnamed: 0                          order_id  order_item_id  \
# 0           0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1           1  00018f77f2f0320c557190d7a144bdd3              1
# 2           2  000229ec398224ef6ca0657da4fc703e              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
#
#    shipping_limit_date  price  freight_value
# 0  2017-09-19 09:45:35   58.9          13.29
# 1  2017-05-03 11:05:13  239.9          19.93
# 2  2018-01-18 14:48:30  199.0          17.87

# %%
itens.drop('shipping_limit_date', axis=1, inplace=True)

# %% [markdown]
# ### Avaliação

# %%
print(avaliacoes.shape)
avaliacoes.head(3)
# Out:
# (99224, 7)
#    Unnamed: 0.1  Unnamed: 0                         review_id  \
# 0             0           0  7bc2406110b926393aa56f80a40eba40
# 1             1           1  80e641a11e56f04c1ad469d5645fdfde
# 2             2           2  228ce5500dc1d8e020d8d1322874b6f0
#
#                            order_id  review_score review_creation_date  \
# 0  73fc7af87114b39712e6da79b0a377eb             4  2018-01-18 00:00:00
# 1  a548910a1c6147796b98fdf73dbeba33             5  2018-03-10 00:00:00
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5  2018-02-17 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24

# %% [markdown]
# Retira as duplicatas para o mesmo order_id selecionando a avaliação mais recente com base em review_answer_timestamp, pois os dados já estão classificados por hora. Em seguida, retire avaliações duplicadas devido ao problema mencionado acima com pedidos de vários itens e várias avaliações.

# %%
avaliacoes.drop_duplicates(subset=['order_id'], keep='last', ignore_index=True, inplace=True)
avaliacoes.drop_duplicates(subset=['review_id'], keep=False, ignore_index=True, inplace=True)

# %% [markdown]
# Criar um novo atributo para capturar o tempo que cada cliente leva para responder à pesquisa após a compra. Em seguida, solte as colunas de carimbo de data/hora.

# %%
avaliacoes['review_answer_timestamp'] = pd.to_datetime(avaliacoes['review_answer_timestamp'], format='%Y/%m/%d')
avaliacoes['review_creation_date'] = pd.to_datetime(avaliacoes['review_creation_date'], format='%Y/%m/%d')
avaliacoes['review_answer_delay'] = (avaliacoes['review_answer_timestamp'] - avaliacoes['review_creation_date']).dt.days

# %%
avaliacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97597 entries, 0 to 97596
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.1             97597 non-null  int64
#  1   Unnamed: 0               97597 non-null  int64
#  2   review_id                97597 non-null  object
#  3   order_id                 97597 non-null  object
#  4   review_score             97597 non-null  int64
#  5   review_creation_date     97597 non-null  datetime64[ns]
#  6   review_answer_timestamp  97597 non-null  datetime64[ns]
#  7   review_answer_delay      97597 non-null  int64
# dtypes: datetime64[ns](2), int64(4), object(2)
# memory usage: 6.0+ MB

# %%
avaliacoes.head()
# Out:
#    Unnamed: 0                         review_id  \
# 0           0  7bc2406110b926393aa56f80a40eba40
# 1           1  80e641a11e56f04c1ad469d5645fdfde
# 2           2  228ce5500dc1d8e020d8d1322874b6f0
# 3           3  e64fb393e7b32834bb789ff8bb30750e
# 4           4  f7c4243c7fe1938f181bec41a392bdeb
#
#                            order_id  review_score review_creation_date  \
# 0  73fc7af87114b39712e6da79b0a377eb             4           2018-01-18
# 1  a548910a1c6147796b98fdf73dbeba33             5           2018-03-10
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5           2018-02-17
# 3  658677c97b385a9be170737859d3511b             5           2017-04-21
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5           2018-03-01
#
#   review_answer_timestamp  review_answer_delay
# 0     2018-01-18 21:46:59                    0
# 1     2018-03-11 03:05:13                    1
# 2     2018-02-18 14:36:24                    1
# 3     2017-04-21 22:02:06                    0
# 4     2018-03-02 10:26:53                    1

# %%
avaliacoes.to_csv('avaliacoes.csv')

# %% [markdown]
# ## Ordens

# %%
print(ordens.shape)
ordens.head(3)
# Out:
# (99441, 9)
#    Unnamed: 0                          order_id  \
# 0           0  e481f51cbdc54678b7cc49136f2d6af7
# 1           1  53cdb2fc8bc7dce0b6741e2150273451
# 2           2  47770eb9100c2d0c44946d9cf07ec65d
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1  b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 2  41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-10-02 11:07:15          2017-10-04 19:55:00
# 1  2018-07-26 03:24:27          2018-07-26 14:31:00
# 2  2018-08-08 08:55:23          2018-08-08 13:50:00
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2017-10-10 21:25:13                    2017-10-18
# 1           2018-08-07 15:27:45                    2018-08-13
# 2           2018-08-17 18:06:29                    2018-09-04

# %%
ordens.loc[:,'order_purchase_timestamp'] = pd.to_datetime(ordens['order_purchase_timestamp'],
                                                              format='%Y/%m/%d').dt.date
ordens.loc[:,'order_delivered_customer_date'] = pd.to_datetime(ordens['order_delivered_customer_date'],
                                                              format='%Y/%m/%d').dt.date
ordens.loc[:,'order_estimated_delivery_date'] = pd.to_datetime(ordens['order_estimated_delivery_date'],
                                                              format='%Y/%m/%d').dt.date


ordens['data_estimada_entrega'] = (ordens['order_estimated_delivery_date'] 
                                            - ordens['order_purchase_timestamp']).astype('timedelta64[D]')
ordens['data_real_entrega'] = (ordens['order_delivered_customer_date'] 
                                            - ordens['order_purchase_timestamp']).astype('timedelta64[D]')

# %%
ordens['year'] = pd.to_datetime(ordens['order_purchase_timestamp'], format='%Y/%m/%d').dt.year

# %%
ordens = ordens[(~ordens['order_status'].isin(['canceled', 'unavailable']))]

cols_to_drop = ['order_approved_at', 'order_delivered_carrier_date', 
               'order_delivered_customer_date', 'order_estimated_delivery_date'] 
ordens = ordens.drop(cols_to_drop, axis=1)
ordens.head(3)
# Out:
#    Unnamed: 0                          order_id  \
# 0           0  e481f51cbdc54678b7cc49136f2d6af7
# 1           1  53cdb2fc8bc7dce0b6741e2150273451
# 2           2  47770eb9100c2d0c44946d9cf07ec65d
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  9ef432eb6251297304e76186b10a928d    delivered               2017-10-02
# 1  b0830fb4747a6c6d20dea0b8c802d7ef    delivered               2018-07-24
# 2  41ce2a54c0b03bf3443c3d931a367089    delivered               2018-08-08
#
#    data_estimada_entrega  data_real_entrega  year
# 0                   16.0                8.0  2017
# 1                   20.0               14.0  2018
# 2                   27.0                9.0  2018

# %%
ordens.to_csv('ordens.csv')

# %% [markdown]
# ## Produto

# %%
print(produtos.shape)
produtos.head(3)
# Out:
# (32340, 7)
#    Unnamed: 0                        product_id product_category_name  \
# 0           0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1           1  3aa071139cb16b67ca9e5dea641aaa2f                 artes
# 2           2  96bd76ec8810374ed1b65e291975717f         esporte_lazer
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0

# %%
produtos.isna().sum()
# Out:
# Unnamed: 0               0
# product_id               0
# product_category_name    0
# product_weight_g         0
# product_length_cm        0
# product_height_cm        0
# product_width_cm         0
# dtype: int64

# %%
df_prov = pd.read_csv("Data/df_provisorio.csv")

# %%
df_prov
# Out:
#         Unnamed: 0.2                         seller_id  \
# 0                  0  6d803cb79cc31c41c4c789a75933b3c7
# 1                  1  6d803cb79cc31c41c4c789a75933b3c7
# 2                  2  8e6d7754bc7e0f22c96d255ebda59eba
# 3                  3  a1043bafd471dff536d0c462352beb48
# 4                  4  a1043bafd471dff536d0c462352beb48
# ...              ...                               ...
# 113126        113126  5343d0649eca2a983820bfe93fc4d17e
# 113127        113127  46dc3b2cc0980fb8ec44634e21d2718e
# 113128        113128  17ca9b9e9b9ef8fdb529001b49ebb50f
# 113129        113129  8d956fec2e4337affcb520f56fd8cbfd
# 113130        113130  7e3f87d16fb353f408d467e74fbd8014
#
#         seller_zip_code_prefix            seller_city seller_state  \
# 0                      14600.0   sao joaquim da barra           SP
# 1                      14600.0   sao joaquim da barra           SP
# 2                      12233.0    sao jose dos campos           SP
# 3                      37175.0               ilicinea           MG
# 4                      37175.0               ilicinea           MG
# ...                        ...                    ...          ...
# 113126                  9270.0            santo andre           SP
# 113127                 22240.0         rio de janeiro           RJ
# 113128                 32677.0                  betim           MG
# 113129                  9780.0  sao bernardo do campo           SP
# 113130                  4809.0              sao paulo           SP
#
#         Unnamed: 0.1                          order_id  order_item_id  \
# 0            51033.0  73fc7af87114b39712e6da79b0a377eb            1.0
# 1            51034.0  73fc7af87114b39712e6da79b0a377eb            2.0
# 2            72472.0  a548910a1c6147796b98fdf73dbeba33            1.0
# 3           109962.0  f9e4b658b201a9f2ecdecbb34bed034b            1.0
# 4            44664.0  658677c97b385a9be170737859d3511b            1.0
# ...              ...                               ...            ...
# 113126       18516.0  2a8c23fee101d4d5662fa670396eb8da            1.0
# 113127       15306.0  22ec9f0669f784db00fa86d035cf8602            1.0
# 113128       37835.0  55d4004744368f5571d1f590031933e4            1.0
# 113129       52329.0  7725825d039fc1f0ceb7635e3f7d9206            1.0
# 113130       63219.0  90531360ecb1eec2a1fbb265a0db0508            1.0
#
#                               product_id  shipping_limit_date   price  \
# 0       fd25ab760bfbba13c198fa3b4f1a0cd3  2018-01-18 15:47:59  185.00
# 1       fd25ab760bfbba13c198fa3b4f1a0cd3  2018-01-18 15:47:59  185.00
# 2       be0dbdc3d67d55727a65d4cd696ca73c  2018-03-06 12:48:39   79.79
# 3       d1c427060a0f73f6b889a5c7c61f2ac4  2018-02-08 10:31:15  149.00
# 4       52c80cedd4e90108bf4fa6a206ef6b03  2017-04-13 17:55:19  179.99
# ...                                  ...                  ...     ...
# 113126  4fb209073dc2ab6a6d3c259a7c285501  2018-07-02 17:30:37  226.77
# 113127  3a33c980b62eb1ef3b8ae61b6fc6fe55  2017-12-07 22:08:00  199.99
# 113128  8ba0118a487ec8671aed57e5ef846574  2018-03-22 10:08:04  215.97
# 113129  73a7fbf8c1048131f3b531af31bcdf0e  2018-06-26 18:15:29   50.95
# 113129                      2018-07-16       99222
# 113130                      2017-07-12       99223
#
#                                review_id  review_score review_creation_date  \
# 0       7bc2406110b926393aa56f80a40eba40             4  2018-01-18 00:00:00
# 1       7bc2406110b926393aa56f80a40eba40             4  2018-01-18 00:00:00
# 2       80e641a11e56f04c1ad469d5645fdfde             5  2018-03-10 00:00:00
# 3       228ce5500dc1d8e020d8d1322874b6f0             5  2018-02-17 00:00:00
# 4       e64fb393e7b32834bb789ff8bb30750e             5  2017-04-21 00:00:00
# ...                                  ...           ...                  ...
# 113126  574ed12dd733e5fa530cfd4bbf39d7c9             5  2018-07-07 00:00:00
# 113127  f3897127253a9592a73be9bdfdf4ed7a             5  2017-12-09 00:00:00
# 113128  b3de70c89b1510c4cd3d0649fd302472             5  2018-03-22 00:00:00
# 113129  1adeb9d84d72fe4e337617733eb85149             4  2018-07-01 00:00:00
# 113130  efe49f1d6f951dd88b51e6ccd4cc548f             1  2017-07-03 00:00:00
#
#        review_answer_timestamp
# 0          2018-01-18 21:46:59
# 1          2018-01-18 21:46:59
# 2          2018-03-11 03:05:13
# 3          2018-02-18 14:36:24
# 4          2017-04-21 22:02:06
# ...                        ...
# 113126     2018-07-14 17:18:30
# 113127     2017-12-11 20:06:42
# 113128     2018-03-23 09:10:43
# 113129     2018-07-02 12:59:13
# 113130     2017-07-03 21:01:49
#
# [113131 rows x 40 columns]

# %%
df_prov.drop(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'review_id'],axis=1, inplace=True)

# %%
times_cols = ['order_purchase_timestamp_y', 'order_approved_at_y', 'order_delivered_carrier_date_y', 'order_delivered_customer_date_y', 'order_estimated_delivery_date_y', 'review_creation_date', 'review_answer_timestamp'  ]
for col in times_cols:
    df_prov[col] = pd.to_datetime(df_prov[col])

# %%
df_prov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113131 entries, 0 to 113130
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   seller_id                        112372 non-null  object
#  1   seller_zip_code_prefix           112372 non-null  float64
#  2   seller_city                      112372 non-null  object
#  3   seller_state                     112372 non-null  object
#  4   order_id                         113131 non-null  object
#  5   order_item_id                    112372 non-null  float64
#  6   product_id                       112372 non-null  object
#  7   shipping_limit_date              112372 non-null  object
#  8   price                            112372 non-null  float64
#  9   freight_value                    112372 non-null  float64
#  10  customer_id_x                    113131 non-null  object
#  11  order_status_x                   113131 non-null  object
#  12  order_purchase_timestamp_x       113131 non-null  object
#  13  order_approved_at_x              113131 non-null  object
#  14  order_delivered_carrier_date_x   113131 non-null  object
#  15  order_delivered_customer_date_x  113131 non-null  object
#  16  order_estimated_delivery_date_x  113131 non-null  object
#  17  Unnamed: 0_x                     110773 non-null  float64
#  18  product_category_name            110773 non-null  object
#  19  product_description_lenght       110773 non-null  float64
#  20  product_photos_qty               110773 non-null  float64
#  21  product_weight_g                 110773 non-null  float64
#  22  product_length_cm                110773 non-null  float64
#  23  product_height_cm                110773 non-null  float64
#  24  product_width_cm                 110773 non-null  float64
#  25  Unnamed: 0_y                     113131 non-null  int64
#  26  customer_id_y                    113131 non-null  object
#  27  order_status_y                   113131 non-null  object
#  28  order_purchase_timestamp_y       113131 non-null  datetime64[ns]
#  29  order_approved_at_y              113131 non-null  datetime64[ns]
#  30  order_delivered_carrier_date_y   113131 non-null  datetime64[ns]
#  31  order_delivered_customer_date_y  113131 non-null  datetime64[ns]
#  32  order_estimated_delivery_date_y  113131 non-null  datetime64[ns]
#  33  review_score                     113131 non-null  int64
#  34  review_creation_date             113131 non-null  datetime64[ns]
#  35  review_answer_timestamp          113131 non-null  datetime64[ns]
# dtypes: datetime64[ns](7), float64(11), int64(2), object(16)
# memory usage: 31.1+ MB

# %%
df_prov.head(2)
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  6d803cb79cc31c41c4c789a75933b3c7                 14600.0
# 1  6d803cb79cc31c41c4c789a75933b3c7                 14600.0
#
#             seller_city seller_state                          order_id  \
# 0  sao joaquim da barra           SP  73fc7af87114b39712e6da79b0a377eb
# 1  sao joaquim da barra           SP  73fc7af87114b39712e6da79b0a377eb
#
#    order_item_id                        product_id  shipping_limit_date  \
# 0            1.0  fd25ab760bfbba13c198fa3b4f1a0cd3  2018-01-18 15:47:59
# 1            2.0  fd25ab760bfbba13c198fa3b4f1a0cd3  2018-01-18 15:47:59
#
#    price  freight_value                     customer_id_x order_status_x  \
# 0  185.0          13.63  41dcb106f807e993532d446263290104      delivered
# 1  185.0          13.63  41dcb106f807e993532d446263290104      delivered
#
#   order_purchase_timestamp_x  order_approved_at_x  \
# 0        2018-01-11 15:30:49  2018-01-11 15:47:59
# 1        2018-01-11 15:30:49  2018-01-11 15:47:59
#
#   order_delivered_carrier_date_x order_delivered_customer_date_x  \
# 0            2018-01-12 21:57:22             2018-01-17 18:42:41
# 1            2018-01-12 21:57:22             2018-01-17 18:42:41
#
#   order_estimated_delivery_date_x  Unnamed: 0_x product_category_name  \
# 0                      2018-02-02       24450.0         esporte_lazer
# 1                      2018-02-02       24450.0         esporte_lazer
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       858.0                 1.0            1300.0
# 1                       858.0                 1.0            1300.0
#
#    product_length_cm  product_height_cm  product_width_cm  Unnamed: 0_y  \
# 0               30.0               30.0              35.0          1871
# 1               30.0               30.0              35.0          1871
#
#                       customer_id_y order_status_y order_purchase_timestamp_y  \
# 0  41dcb106f807e993532d446263290104      delivered        2018-01-11 15:30:49
# 1  41dcb106f807e993532d446263290104      delivered        2018-01-11 15:30:49
#
#   order_approved_at_y order_delivered_carrier_date_y  \
# 0 2018-01-11 15:47:59            2018-01-12 21:57:22
# 1 2018-01-11 15:47:59            2018-01-12 21:57:22
#
#   order_delivered_customer_date_y order_estimated_delivery_date_y  \
# 0             2018-01-17 18:42:41                      2018-02-02
# 1             2018-01-17 18:42:41                      2018-02-02
#
#    review_score review_creation_date review_answer_timestamp
# 0             4           2018-01-18     2018-01-18 21:46:59
# 1             4           2018-01-18     2018-01-18 21:46:59

# %%
produtos['review_creation_date'] = produtos['review_creation_date'].fillna('not_reported')
produtos.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 produtos['review_creation_date'] = produtos['review_creation_date'].fillna('not_reported')
#       2 produtos.head(3)
#
# NameError: name 'produtos' is not defined

# %%
times_cols = ['order_purchase_timestamp', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'order_estimated_delivery_date', 'order_delivered_customer_date']
for col in times_cols:
    ordens[col] = pd.to_datetime(ordens[col])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 3
#       1 times_cols = ['order_purchase_timestamp', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'order_estimated_delivery_date', 'order_delivered_customer_date']
#       2 for col in times_cols:
# ----> 3     ordens[col] = pd.to_datetime(ordens[col])
#
# NameError: name 'ordens' is not defined

# %% [markdown]
# ## DF_Provisório

# %%
df_prov['tempo_resposta'] = (df_prov['review_creation_date'] - df_prov['review_answer_timestamp']).astype('timedelta64[D]')

# %%
df_prov['prazo_entrega']= (df_prov['order_estimated_delivery_date_y'] - df_prov['order_delivered_customer_date_y']).astype('timedelta64[D]')

# %%
df_prov
# Out:
#                                seller_id  seller_zip_code_prefix  \
# 0       6d803cb79cc31c41c4c789a75933b3c7                 14600.0
# 1       6d803cb79cc31c41c4c789a75933b3c7                 14600.0
# 2       8e6d7754bc7e0f22c96d255ebda59eba                 12233.0
# 3       a1043bafd471dff536d0c462352beb48                 37175.0
# 4       a1043bafd471dff536d0c462352beb48                 37175.0
# ...                                  ...                     ...
# 113126  5343d0649eca2a983820bfe93fc4d17e                  9270.0
# 113127  46dc3b2cc0980fb8ec44634e21d2718e                 22240.0
# 113128  17ca9b9e9b9ef8fdb529001b49ebb50f                 32677.0
# 113129  8d956fec2e4337affcb520f56fd8cbfd                  9780.0
# 113130  7e3f87d16fb353f408d467e74fbd8014                  4809.0
#
#                   seller_city seller_state                          order_id  \
# 0        sao joaquim da barra           SP  73fc7af87114b39712e6da79b0a377eb
# 1        sao joaquim da barra           SP  73fc7af87114b39712e6da79b0a377eb
# 2         sao jose dos campos           SP  a548910a1c6147796b98fdf73dbeba33
# 3                    ilicinea           MG  f9e4b658b201a9f2ecdecbb34bed034b
# 4                    ilicinea           MG  658677c97b385a9be170737859d3511b
# ...                       ...          ...                               ...
# 113126            santo andre           SP  2a8c23fee101d4d5662fa670396eb8da
# 113127         rio de janeiro           RJ  22ec9f0669f784db00fa86d035cf8602
# 113128                  betim           MG  55d4004744368f5571d1f590031933e4
# 113129  sao bernardo do campo           SP  7725825d039fc1f0ceb7635e3f7d9206
# 113130              sao paulo           SP  90531360ecb1eec2a1fbb265a0db0508
#
#         order_item_id                        product_id  shipping_limit_date  \
# 0                 1.0  fd25ab760bfbba13c198fa3b4f1a0cd3  2018-01-18 15:47:59
# 1                 2.0  fd25ab760bfbba13c198fa3b4f1a0cd3  2018-01-18 15:47:59
# 2                 1.0  be0dbdc3d67d55727a65d4cd696ca73c  2018-03-06 12:48:39
# 3                 1.0  d1c427060a0f73f6b889a5c7c61f2ac4  2018-02-08 10:31:15
# 4                 1.0  52c80cedd4e90108bf4fa6a206ef6b03  2017-04-13 17:55:19
# ...               ...                               ...                  ...
# 113126            1.0  4fb209073dc2ab6a6d3c259a7c285501  2018-07-02 17:30:37
# 113127            1.0  3a33c980b62eb1ef3b8ae61b6fc6fe55  2017-12-07 22:08:00
# 113128            1.0  8ba0118a487ec8671aed57e5ef846574  2018-03-22 10:08:04
#         product_description_lenght  product_photos_qty  product_weight_g  \
# 0                            858.0                 1.0            1300.0
# 1                            858.0                 1.0            1300.0
# 2                            493.0                 1.0             245.0
# 3                           1893.0                 1.0            6550.0
# 4                           2188.0                 2.0            7650.0
# ...                            ...                 ...               ...
# 113126                       623.0                 1.0            7250.0
# 113127                       465.0                 1.0            2363.0
# 113128                       283.0                 3.0            4100.0
# 113129                       998.0                 5.0             600.0
# 113130                       482.0                 2.0             500.0
#
#         product_length_cm  product_height_cm  product_width_cm  Unnamed: 0_y  \
# 0                    30.0               30.0              35.0          1871
# 1                    30.0               30.0              35.0          1871
# 2                    19.0               14.0              14.0         90488
# 3                    20.0               20.0              20.0         78882
# 4                    20.0               20.0              20.0         27557
# ...                   ...                ...               ...           ...
# 113126              100.0               25.0              25.0         66506
# 113127               23.0               27.0              19.0         84918
# 113128               40.0               37.0              29.0          9817
# 113129               16.0               10.0              11.0         29006
# 113130               35.0                5.0              15.0         51236
#
#                            customer_id_y order_status_y  \
# 0       41dcb106f807e993532d446263290104      delivered
# 1       41dcb106f807e993532d446263290104      delivered
# 2       8a2e7ef9053dea531e4dc76bd6d853e6      delivered
# 3       e226dfed6544df5b7b87a48208690feb      delivered
# 4       de6dff97e5f1ba84a3cd9a3bc97df5f6      delivered
# ...                                  ...            ...
# 113126  d8c466a3e7c4cda36cd4ae7d577f44f4      delivered
# 113127  d0d7086dea6fcf42b9b690b9f3745c58      delivered
# 113128  fcc7b1caafe3b77fd587bab964c4d1fb      delivered
# 113129  3aa00401736823c73e9fe8683328fa6b      delivered
# 113130  f6fff47846276bed044b63474bd38884      delivered
#
#        order_purchase_timestamp_y order_approved_at_y  \
# 0             2018-01-11 15:30:49 2018-01-11 15:47:59
# 1             2018-01-11 15:30:49 2018-01-11 15:47:59
# 2             2018-02-28 12:25:19 2018-02-28 12:48:39
# 3             2018-02-03 09:56:22 2018-02-03 10:33:41
# 4             2017-04-09 17:41:13 2017-04-09 17:55:19
# ...                           ...                 ...
# 113126        2018-06-27 17:31:29 2018-06-28 17:30:45
# 113127        2017-12-03 21:45:23 2017-12-03 22:08:00
# 113128        2018-03-18 09:52:19 2018-03-18 10:08:04
# 113129        2018-06-22 16:47:28 2018-06-22 18:15:29
# 113130        2017-06-29 10:43:25 2017-06-30 02:45:15
#
#        order_delivered_carrier_date_y order_delivered_customer_date_y  \
# 0                 2018-01-12 21:57:22             2018-01-17 18:42:41
# 1                 2018-01-12 21:57:22             2018-01-17 18:42:41
# 2                 2018-03-02 19:08:15             2018-03-09 23:17:20
# 3                 2018-02-06 16:18:28             2018-02-16 17:28:48
# 4                 2017-04-10 14:24:47             2017-04-20 09:08:35
# ...                               ...                             ...
# 113126            2018-06-29 14:25:00             2018-07-06 13:22:37
# 113127            2017-12-07 19:17:29             2017-12-08 17:19:00
# 113128            2018-03-19 23:51:29             2018-03-21 17:44:08
# 113129            2018-06-25 12:58:00             2018-06-30 12:57:51
# 113130            2017-06-30 13:53:54             2017-07-02 09:44:54
#
#        order_estimated_delivery_date_y  review_score review_creation_date  \
# 0                           2018-02-02             4           2018-01-18
# 1                           2018-02-02             4           2018-01-18
# 2                           2018-03-14             5           2018-03-10
# 3                           2018-03-09             5           2018-02-17
# 4                           2017-05-10             5           2017-04-21
# ...                                ...           ...                  ...
# 113126                      2018-07-20             5           2018-07-07
# 113127                      2017-12-20             5           2017-12-09
# 113128                      2018-04-06             5           2018-03-22
# 113129                      2018-07-16             4           2018-07-01
# 113130                      2017-07-12             1           2017-07-03
#
#        review_answer_timestamp  tempo_resposta  prazo_entrega
# 0          2018-01-18 21:46:59            -1.0           15.0
# 1          2018-01-18 21:46:59            -1.0           15.0
# 2          2018-03-11 03:05:13            -2.0            4.0
# 3          2018-02-18 14:36:24            -2.0           20.0
# 4          2017-04-21 22:02:06            -1.0           19.0
# ...                        ...             ...            ...
# 113126     2018-07-14 17:18:30            -8.0           13.0
# 113127     2017-12-11 20:06:42            -3.0           11.0
# 113128     2018-03-23 09:10:43            -2.0           15.0
# 113129     2018-07-02 12:59:13            -2.0           15.0
# 113130     2017-07-03 21:01:49            -1.0            9.0
#
# [113131 rows x 38 columns]

# %%
df_prov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113131 entries, 0 to 113130
# Data columns (total 38 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   seller_id                        112372 non-null  object
#  1   seller_zip_code_prefix           112372 non-null  float64
#  2   seller_city                      112372 non-null  object
#  3   seller_state                     112372 non-null  object
#  4   order_id                         113131 non-null  object
#  5   order_item_id                    112372 non-null  float64
#  6   product_id                       112372 non-null  object
#  7   shipping_limit_date              112372 non-null  object
#  8   price                            112372 non-null  float64
#  9   freight_value                    112372 non-null  float64
#  10  customer_id_x                    113131 non-null  object
#  11  order_status_x                   113131 non-null  object
#  12  order_purchase_timestamp_x       113131 non-null  object
#  13  order_approved_at_x              113131 non-null  object
#  14  order_delivered_carrier_date_x   113131 non-null  object
#  15  order_delivered_customer_date_x  113131 non-null  object
#  16  order_estimated_delivery_date_x  113131 non-null  object
#  17  Unnamed: 0_x                     110773 non-null  float64
#  18  product_category_name            110773 non-null  object
#  19  product_description_lenght       110773 non-null  float64
#  20  product_photos_qty               110773 non-null  float64
#  21  product_weight_g                 110773 non-null  float64
#  22  product_length_cm                110773 non-null  float64
#  23  product_height_cm                110773 non-null  float64
#  24  product_width_cm                 110773 non-null  float64
#  25  Unnamed: 0_y                     113131 non-null  int64
#  26  customer_id_y                    113131 non-null  object
#  27  order_status_y                   113131 non-null  object
#  28  order_purchase_timestamp_y       113131 non-null  datetime64[ns]
#  29  order_approved_at_y              113131 non-null  datetime64[ns]
#  30  order_delivered_carrier_date_y   113131 non-null  datetime64[ns]
#  31  order_delivered_customer_date_y  113131 non-null  datetime64[ns]
#  32  order_estimated_delivery_date_y  113131 non-null  datetime64[ns]
#  33  review_score                     113131 non-null  int64
#  34  review_creation_date             113131 non-null  datetime64[ns]
#  35  review_answer_timestamp          113131 non-null  datetime64[ns]
#  36  tempo_resposta                   113131 non-null  float64
#  37  prazo_entrega                    113131 non-null  float64
# dtypes: datetime64[ns](7), float64(13), int64(2), object(16)
# memory usage: 32.8+ MB

# %%
df_prov.to_csv('df_prov1.csv')
